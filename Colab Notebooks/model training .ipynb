# %% [markdown]
# import **kaggle.json** file

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download ashfakyeafi/spam-email-classification

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/spam-email-classification.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
#This block is only use for importing necessary libarary
#Core library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#Using plotly
import plotly.express as px
#using word cloude
from wordcloud import WordCloud
#using sklearn library
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import CountVectorizer

from sklearn.naive_bayes import MultinomialNB

# %%
df = pd.read_csv('/content/email.csv')

# %%
df.head()

# %%
df.shape

# %%
df.columns

# %%
df.duplicated().sum()

# %% [markdown]
# without **inplace=True** it remain same repeted.

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()

# %%
df.shape

# %%
df.isnull().sum()

# %% [markdown]
# This code filters the DataFrame df to keep only rows where the **Category** column is either **ham** or **spam**, and then counts the occurrences of each category.

# %%
df = df[df['Category'].isin(['ham','spam'])]
labels_count = df['Category'].value_counts()

# %%
fig = px.pie(df, values=labels_count.values, names=labels_count.index,hole=0.5, title='Ham & Spam')
fig.show()

# %%
def plot_wordcloude(text,title):
  wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

  plt.figure(figsize=(10, 5))
  plt.imshow(wordcloud, interpolation='bilinear')
  plt.axis('off')
  plt.title(title)
  plt.show()

# %%
Ham_mail = ''.join(df[df['Category']=='ham']['Message'])

# %%
plot_wordcloude(Ham_mail,'Ham Mail')

# %%
X=df['Message']
y=df['Category']

# %%
X.head()
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: Message, dtype: object

# %%
le = LabelEncoder()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
vectorizer = CountVectorizer()

# %%
X_train = vectorizer.fit_transform(X_train)

# %%
X_train.toarray()

# %% [markdown]
# for text use Knife Based **Multi Nomial algorithm**

# %%
model = MultinomialNB()

# %%
model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
model.score(X_train, y_train)
# Out:
# 0.993342981186686
