# %%
# pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,

# use hash for comment.
Panel deta,
Type:
Series(one column)
Deta Frame(Multiple colum)

Ecell vs csv, dataset source: caggel, uci repository, google deta set search.
Under fit(missing value), overfit(duplicate), best fit.

https://github.com/ronimahabub2021

"""
use it for best multi line comment
"""

# %%
import pandas as pd
from google.colab import files

data = [1,2,3,4, 'pythone']
data
a = pd.Series(data)
a.info()
a.dtypes
b = pd.DataFrame(a)
b
b.info()
b.columns
b.shape

# %%
import pandas as pd

s = {10, 20, 30, 40, 50}
l = list(s)

ser = pd.Series(l)
print(ser)

df = pd.DataFrame(ser)
print(df)

# %%
import pandas as pd

data = {'a': 1, 'b': 2, 'c': 3}
a = pd.Series(data)
b = pd.DataFrame(a)

print(a)
a.info()

print(b)
b.info()

# %%
import pandas as pd

data = {'col1': [1, 2, 3], 'col2': ['X', 'Y', 'Z']}
a = pd.DataFrame(data)
print(a)

# %%
import pandas as pd

tuple_data = (100, 200, 300)
tuple_series = pd.Series(tuple_data)
print("\nSeries from Tuple:")
display(tuple_series)

# %%
import pandas as pd

list_of_tuples_data = [(10, 'Apple'), (20, 'Banana'), (30, 'Cherry')]
list_of_tuples_df = pd.DataFrame(list_of_tuples_data, columns=['Quantity', 'Fruit'])
display(list_of_tuples_df)

# %%
files.upload()

# %%
df = pd.read_csv('Heart_Disease_Prediction.csv')
# df.head()
# df.shape
# df.info()
# df.isnull().sum()
# df.dropna()
# df.fillna(0) #You can use dictionry to fill multiple value for multiple column.

# df.columns
# column are called feature.
# target is called label.

# df.Age
# Out:
# Index(['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120',
#        'EKG results', 'Max HR', 'Exercise angina', 'ST depression',
#        'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease'],
#       dtype='object')
